# %%
import pandas as pd

# %%
pd.read_csv('green_tripdata_2019-09.csv.gz', nrows=100)
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1          2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2          2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3          2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4          2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-09-01 00:40:55   2019-09-01 00:48:35                  N
# 96         2  2019-09-01 00:13:52   2019-09-01 00:21:47                  N
# 97         2  2019-09-01 00:37:24   2019-09-01 01:02:31                  N
# 98         2  2019-09-01 00:22:15   2019-09-01 00:29:52                  N
# 99         2  2019-09-01 00:11:53   2019-09-01 00:30:31                  N
#
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql://root:root@localhost:5432/ny_taxi")

# %%
df_iter = pd.read_csv('green_tripdata_2019-09.csv.gz', iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %%
df.head(n=0).to_sql(name='green_taxi_data_sep_2019', con=engine, if_exists='replace')
# Out:
# 0

# %%
df.to_sql(name='green_taxi_data_sep_2019', con=engine, if_exists='append')
# Out:
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.to_sql(name='green_taxi_data_sep_2019', con=engine, if_exists='append')
    t_end = time()
    
    print("Inserted another chunk ..., took %.3f second" % (t_end - t_start))
# Out:
# Inserted another chunk ..., took 4.361 second
# Inserted another chunk ..., took 4.251 second
# /var/folders/32/s15gttv51dv7xnkm979spnh80000gn/T/ipykernel_6319/3289027990.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# Inserted another chunk ..., took 4.339 second
# Inserted another chunk ..., took 1.794 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[23], line 3
#       1 while True:
#       2     t_start = time()
# ----> 3     df = next(df_iter)
#       4     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       5     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1624, in TextFileReader.__next__(self)
#    1622 def __next__(self) -> DataFrame:
# ...
